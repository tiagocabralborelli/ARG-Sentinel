# %%
import glob
import pandas as pd
from Bio import SeqIO

# %% [markdown]
# **TREAT**

# %%
fastas = glob.glob("/home/tiago/documentos/github/ARG-Sentinel/genomes_hc/" + "*.fasta")
for file in fastas:
	for record in SeqIO.parse(f"{file}","fasta"):
		if len(record.seq) > 200:
			new_file = open(f"treated_{file.split('/')[-1]}","a")
			new_file.write(f"{record.id}\n")
			new_file.write(f"{record.seq}\n")
			new_file.close()

# %% [markdown]
# **GET INTO**

# %%
files = glob.glob("/home/tiago/documentos/github/ARG-Sentinel/suberror/*.txt")
genome = []
node = []
start = []
end = []

for f in files:
    txt = open(f,'r')
    for lines in txt:
        if lines.startswith("NODE"):
            genome.append(f.split("/")[-1].split(".")[0])
            
            node.append(lines.split("\t")[0])
                        
            start.append(lines.split("\t")[2].split("..")[0])
                                      
            end.append(lines.split("\t")[2].split("..")[1])
                        
                        
df = pd.DataFrame({"genome":genome, "node":node, "start":start, "end":end})

# %% [markdown]
# **TRIM**

# %%
df.to_csv("error_info.csv")

# %%
n = ["NODE_22_length_73939_cov_13.042389", 
     "NODE_37_length_43294_cov_12.460632", 
     "NODE_42_length_42978_cov_16.990438", 
     "NODE_15_length_136795_cov_22.099162",
     "NODE_34_length_63067_cov_25.930044",
     "NODE_44_length_43061_cov_24.463410",
     "NODE_56_length_2305_cov_620.290118",
     "NODE_41_length_4753_cov_20.978728",
     "NODE_27_length_10506_cov_41.427597",
     "NODE_43_length_2345_cov_2403.472395",
     "NODE_18_length_24824_cov_61.573873"]

# %%
fasta = glob.glob("/home/tiago/documentos/github/ARG-Sentinel/genomes_hc/*.fasta")

# %%
for files in fasta:
    for record in SeqIO.parse(files,'fasta'):
        for tag in n:
            if record.id == tag:
                file = open(f"/home/tiago/documentos/github/ARG-Sentinel/suberror/plasmids_annot/{record.id}.fasta","w")
                file.write(f">{record.id}\n")
                file.write(f"{record.seq}\n")
                file.close()

# %% [markdown]
# **PROKKA**

# %%
# !prokka --outdir ~/documentos/github/ARG-Sentinel/suberror/plasmids_annot/annot/pEC126M3N22 --prefix pEC126M3N22 ~/documentos/github/ARG-Sentinel/suberror/plasmids_annot/pEC126M3N22.fasta
# Out:
# [20:07:09] This is prokka 1.13
# [20:07:09] Written by Torsten Seemann <torsten.seemann@gmail.com>
# [20:07:09] Homepage is https://github.com/tseemann/prokka
# [20:07:09] Local time is Wed Jun 24 20:07:09 2020
# [20:07:09] You are tiago
# [20:07:09] Operating system is linux
# [20:07:09] You have BioPerl 1.007002
# [20:07:09] System has 12 cores.
# [20:07:09] Will use maximum of 8 cores.
# [20:07:09] Annotating as >>> Bacteria <<<
# [20:07:09] Generating locus_tag from '/home/tiago/documentos/github/ARG-Sentinel/suberror/plasmids_annot/pEC126M3N22.fasta' contents.
# [20:07:09] Setting --locustag IBFBDDFI from MD5 2bfbddf2e61f115c0489be2a38a06e9e
# [20:07:09] Creating new output folder: /home/tiago/documentos/github/ARG-Sentinel/suberror/plasmids_annot/annot/pEC126M3N22
# [20:07:09] Running: mkdir -p \/home\/tiago\/documentos\/github\/ARG\-Sentinel\/suberror\/plasmids_annot\/annot\/pEC126M3N22
# [20:07:09] Using filename prefix: pEC126M3N22.XXX
# [20:07:09] Setting HMMER_NCPU=1
# ...

# %%
# !prokka --outdir ~/documentos/github/ARG-Sentinel/suberror/plasmids_annot/annot/pEC537BN37 --prefix pEC537BN37 ~/documentos/github/ARG-Sentinel/suberror/plasmids_annot/pEC537BN37.fasta
# Out:
# [20:07:26] This is prokka 1.13
# [20:07:26] Written by Torsten Seemann <torsten.seemann@gmail.com>
# [20:07:26] Homepage is https://github.com/tseemann/prokka
# [20:07:26] Local time is Wed Jun 24 20:07:26 2020
# [20:07:26] You are tiago
# [20:07:26] Operating system is linux
# [20:07:26] You have BioPerl 1.007002
# [20:07:26] System has 12 cores.
# [20:07:26] Will use maximum of 8 cores.
# [20:07:26] Annotating as >>> Bacteria <<<
# [20:07:26] Generating locus_tag from '/home/tiago/documentos/github/ARG-Sentinel/suberror/plasmids_annot/pEC537BN37.fasta' contents.
# [20:07:26] Setting --locustag CAFGOAIM from MD5 caf08a269d86bc6c5d965155b3f2280d
# [20:07:26] Creating new output folder: /home/tiago/documentos/github/ARG-Sentinel/suberror/plasmids_annot/annot/pEC537BN37
# [20:07:26] Running: mkdir -p \/home\/tiago\/documentos\/github\/ARG\-Sentinel\/suberror\/plasmids_annot\/annot\/pEC537BN37
# [20:07:26] Using filename prefix: pEC537BN37.XXX
# [20:07:26] Setting HMMER_NCPU=1
# ...

# %%
# !prokka --outdir ~/documentos/github/ARG-Sentinel/suberror/plasmids_annot/annot/pKP125M3N44 --prefix pKP125M3N44 ~/documentos/github/ARG-Sentinel/suberror/plasmids_annot/pKP125M3N44.fasta
# Out:
# [20:07:31] This is prokka 1.13
# [20:07:31] Written by Torsten Seemann <torsten.seemann@gmail.com>
# [20:07:31] Homepage is https://github.com/tseemann/prokka
# [20:07:31] Local time is Wed Jun 24 20:07:31 2020
# [20:07:31] You are tiago
# [20:07:31] Operating system is linux
# [20:07:31] You have BioPerl 1.007002
# [20:07:31] System has 12 cores.
# [20:07:31] Will use maximum of 8 cores.
# [20:07:31] Annotating as >>> Bacteria <<<
# [20:07:31] Generating locus_tag from '/home/tiago/documentos/github/ARG-Sentinel/suberror/plasmids_annot/pKP125M3N44.fasta' contents.
# [20:07:31] Setting --locustag LONAPIGH from MD5 587a9201a21a020bfc6878d460da3ddf
# [20:07:31] Creating new output folder: /home/tiago/documentos/github/ARG-Sentinel/suberror/plasmids_annot/annot/pKP125M3N44
# [20:07:31] Running: mkdir -p \/home\/tiago\/documentos\/github\/ARG\-Sentinel\/suberror\/plasmids_annot\/annot\/pKP125M3N44
# [20:07:31] Using filename prefix: pKP125M3N44.XXX
# [20:07:31] Setting HMMER_NCPU=1
# ...

# %%
# !prokka --outdir ~/documentos/github/ARG-Sentinel/suberror/plasmids_annot/annot/pKP508BN15 --prefix pKP508BN15 ~/documentos/github/ARG-Sentinel/suberror/plasmids_annot/pKP508BN15.fasta
# Out:
# [20:07:36] This is prokka 1.13
# [20:07:36] Written by Torsten Seemann <torsten.seemann@gmail.com>
# [20:07:36] Homepage is https://github.com/tseemann/prokka
# [20:07:36] Local time is Wed Jun 24 20:07:36 2020
# [20:07:36] You are tiago
# [20:07:36] Operating system is linux
# [20:07:36] You have BioPerl 1.007002
# [20:07:36] System has 12 cores.
# [20:07:36] Will use maximum of 8 cores.
# [20:07:36] Annotating as >>> Bacteria <<<
# [20:07:36] Generating locus_tag from '/home/tiago/documentos/github/ARG-Sentinel/suberror/plasmids_annot/pKP508BN15.fasta' contents.
# [20:07:36] Setting --locustag KLAOMLMB from MD5 45a8656b9ae84c356b705e53150c7b36
# [20:07:36] Creating new output folder: /home/tiago/documentos/github/ARG-Sentinel/suberror/plasmids_annot/annot/pKP508BN15
# [20:07:36] Running: mkdir -p \/home\/tiago\/documentos\/github\/ARG\-Sentinel\/suberror\/plasmids_annot\/annot\/pKP508BN15
# [20:07:36] Using filename prefix: pKP508BN15.XXX
# [20:07:36] Setting HMMER_NCPU=1
# ...

# %%
# !prokka --outdir ~/documentos/github/ARG-Sentinel/suberror/plasmids_annot/annot/pKP508BN34 --prefix pKP508BN34 ~/documentos/github/ARG-Sentinel/suberror/plasmids_annot/pKP508BN34.fasta
# Out:
# [20:07:45] This is prokka 1.13
# [20:07:45] Written by Torsten Seemann <torsten.seemann@gmail.com>
# [20:07:45] Homepage is https://github.com/tseemann/prokka
# [20:07:45] Local time is Wed Jun 24 20:07:45 2020
# [20:07:45] You are tiago
# [20:07:45] Operating system is linux
# [20:07:45] You have BioPerl 1.007002
# [20:07:45] System has 12 cores.
# [20:07:45] Will use maximum of 8 cores.
# [20:07:45] Annotating as >>> Bacteria <<<
# [20:07:45] Generating locus_tag from '/home/tiago/documentos/github/ARG-Sentinel/suberror/plasmids_annot/pKP508BN34.fasta' contents.
# [20:07:45] Setting --locustag EENIKJPO from MD5 ee72439815f63a10b8ab256c41137c19
# [20:07:45] Creating new output folder: /home/tiago/documentos/github/ARG-Sentinel/suberror/plasmids_annot/annot/pKP508BN34
# [20:07:45] Running: mkdir -p \/home\/tiago\/documentos\/github\/ARG\-Sentinel\/suberror\/plasmids_annot\/annot\/pKP508BN34
# [20:07:45] Using filename prefix: pKP508BN34.XXX
# [20:07:45] Setting HMMER_NCPU=1
# ...

# %%
# !prokka --outdir ~/documentos/github/ARG-Sentinel/suberror/plasmids_annot/annot/pKP98M3N42 --prefix pKP98M3N42 ~/documentos/github/ARG-Sentinel/suberror/plasmids_annot/pKP98M3N42.fasta
# Out:
# [20:07:52] This is prokka 1.13
# [20:07:52] Written by Torsten Seemann <torsten.seemann@gmail.com>
# [20:07:52] Homepage is https://github.com/tseemann/prokka
# [20:07:52] Local time is Wed Jun 24 20:07:52 2020
# [20:07:52] You are tiago
# [20:07:52] Operating system is linux
# [20:07:52] You have BioPerl 1.007002
# [20:07:52] System has 12 cores.
# [20:07:52] Will use maximum of 8 cores.
# [20:07:52] Annotating as >>> Bacteria <<<
# [20:07:52] Generating locus_tag from '/home/tiago/documentos/github/ARG-Sentinel/suberror/plasmids_annot/pKP98M3N42.fasta' contents.
# [20:07:52] Setting --locustag FEDIEKEO from MD5 fed2e4e8f247f87e9c978057f9da0876
# [20:07:52] Creating new output folder: /home/tiago/documentos/github/ARG-Sentinel/suberror/plasmids_annot/annot/pKP98M3N42
# [20:07:52] Running: mkdir -p \/home\/tiago\/documentos\/github\/ARG\-Sentinel\/suberror\/plasmids_annot\/annot\/pKP98M3N42
# [20:07:52] Using filename prefix: pKP98M3N42.XXX
# [20:07:52] Setting HMMER_NCPU=1
# ...

# %%
# !prokka --outdir ~/documentos/github/ARG-Sentinel/suberror/plasmids_annot/annot/pSE452BN56 --prefix pSE452BN56 ~/documentos/github/ARG-Sentinel/suberror/plasmids_annot/pSE452BN56.fasta
# Out:
# [20:07:57] This is prokka 1.13
# [20:07:57] Written by Torsten Seemann <torsten.seemann@gmail.com>
# [20:07:57] Homepage is https://github.com/tseemann/prokka
# [20:07:57] Local time is Wed Jun 24 20:07:57 2020
# [20:07:57] You are tiago
# [20:07:57] Operating system is linux
# [20:07:57] You have BioPerl 1.007002
# [20:07:57] System has 12 cores.
# [20:07:57] Will use maximum of 8 cores.
# [20:07:57] Annotating as >>> Bacteria <<<
# [20:07:57] Generating locus_tag from '/home/tiago/documentos/github/ARG-Sentinel/suberror/plasmids_annot/pSE452BN56.fasta' contents.
# [20:07:57] Setting --locustag CFNJLOCI from MD5 cf7358c223d204131098bf8adec771e3
# [20:07:57] Creating new output folder: /home/tiago/documentos/github/ARG-Sentinel/suberror/plasmids_annot/annot/pSE452BN56
# [20:07:57] Running: mkdir -p \/home\/tiago\/documentos\/github\/ARG\-Sentinel\/suberror\/plasmids_annot\/annot\/pSE452BN56
# [20:07:57] Using filename prefix: pSE452BN56.XXX
# [20:07:57] Setting HMMER_NCPU=1
# ...

# %%
# !prokka --outdir ~/documentos/github/ARG-Sentinel/suberror/plasmids_annot/annot/pSE605AN41 --prefix pSE605AN41 ~/documentos/github/ARG-Sentinel/suberror/plasmids_annot/pSE605AN41.fasta
# Out:
# [20:08:00] This is prokka 1.13
# [20:08:00] Written by Torsten Seemann <torsten.seemann@gmail.com>
# [20:08:00] Homepage is https://github.com/tseemann/prokka
# [20:08:00] Local time is Wed Jun 24 20:08:00 2020
# [20:08:00] You are tiago
# [20:08:00] Operating system is linux
# [20:08:00] You have BioPerl 1.007002
# [20:08:00] System has 12 cores.
# [20:08:00] Will use maximum of 8 cores.
# [20:08:00] Annotating as >>> Bacteria <<<
# [20:08:00] Generating locus_tag from '/home/tiago/documentos/github/ARG-Sentinel/suberror/plasmids_annot/pSE605AN41.fasta' contents.
# [20:08:00] Setting --locustag OPMNFDHN from MD5 8967fd173e3569682287945dba21b024
# [20:08:00] Creating new output folder: /home/tiago/documentos/github/ARG-Sentinel/suberror/plasmids_annot/annot/pSE605AN41
# [20:08:00] Running: mkdir -p \/home\/tiago\/documentos\/github\/ARG\-Sentinel\/suberror\/plasmids_annot\/annot\/pSE605AN41
# [20:08:00] Using filename prefix: pSE605AN41.XXX
# [20:08:00] Setting HMMER_NCPU=1
# ...

# %%
# !prokka --outdir ~/documentos/github/ARG-Sentinel/suberror/plasmids_annot/annot/pSW579AN18 --prefix pSW579AN18 ~/documentos/github/ARG-Sentinel/suberror/plasmids_annot/pSW579AN18.fasta
# Out:
# [20:08:03] This is prokka 1.13
# [20:08:03] Written by Torsten Seemann <torsten.seemann@gmail.com>
# [20:08:03] Homepage is https://github.com/tseemann/prokka
# [20:08:03] Local time is Wed Jun 24 20:08:03 2020
# [20:08:03] You are tiago
# [20:08:03] Operating system is linux
# [20:08:03] You have BioPerl 1.007002
# [20:08:03] System has 12 cores.
# [20:08:03] Will use maximum of 8 cores.
# [20:08:03] Annotating as >>> Bacteria <<<
# [20:08:03] Generating locus_tag from '/home/tiago/documentos/github/ARG-Sentinel/suberror/plasmids_annot/pSW579AN18.fasta' contents.
# [20:08:03] Setting --locustag NLAABJDB from MD5 75aab3dbde4a4437829aed46c1fd36dc
# [20:08:03] Creating new output folder: /home/tiago/documentos/github/ARG-Sentinel/suberror/plasmids_annot/annot/pSW579AN18
# [20:08:03] Running: mkdir -p \/home\/tiago\/documentos\/github\/ARG\-Sentinel\/suberror\/plasmids_annot\/annot\/pSW579AN18
# [20:08:03] Using filename prefix: pSW579AN18.XXX
# [20:08:03] Setting HMMER_NCPU=1
# ...

# %%
# !prokka --outdir ~/documentos/github/ARG-Sentinel/suberror/plasmids_annot/annot/pSW732BN27 --prefix pSW732BN27 ~/documentos/github/ARG-Sentinel/suberror/plasmids_annot/pSW732BN27.fasta
# Out:
# [20:08:06] This is prokka 1.13
# [20:08:06] Written by Torsten Seemann <torsten.seemann@gmail.com>
# [20:08:06] Homepage is https://github.com/tseemann/prokka
# [20:08:06] Local time is Wed Jun 24 20:08:06 2020
# [20:08:06] You are tiago
# [20:08:06] Operating system is linux
# [20:08:06] You have BioPerl 1.007002
# [20:08:06] System has 12 cores.
# [20:08:06] Will use maximum of 8 cores.
# [20:08:06] Annotating as >>> Bacteria <<<
# [20:08:06] Generating locus_tag from '/home/tiago/documentos/github/ARG-Sentinel/suberror/plasmids_annot/pSW732BN27.fasta' contents.
# [20:08:06] Setting --locustag LLCPLGJP from MD5 55c95039a4f3b75a902042bed2470ccd
# [20:08:06] Creating new output folder: /home/tiago/documentos/github/ARG-Sentinel/suberror/plasmids_annot/annot/pSW732BN27
# [20:08:06] Running: mkdir -p \/home\/tiago\/documentos\/github\/ARG\-Sentinel\/suberror\/plasmids_annot\/annot\/pSW732BN27
# [20:08:06] Using filename prefix: pSW732BN27.XXX
# [20:08:06] Setting HMMER_NCPU=1
# ...

# %%
# !prokka --outdir ~/documentos/github/ARG-Sentinel/suberror/plasmids_annot/annot/pSW732BN43 --prefix pSW732BN43 ~/documentos/github/ARG-Sentinel/suberror/plasmids_annot/pSW732BN43.fasta
# Out:
# [20:08:09] This is prokka 1.13
# [20:08:09] Written by Torsten Seemann <torsten.seemann@gmail.com>
# [20:08:09] Homepage is https://github.com/tseemann/prokka
# [20:08:09] Local time is Wed Jun 24 20:08:09 2020
# [20:08:09] You are tiago
# [20:08:09] Operating system is linux
# [20:08:09] You have BioPerl 1.007002
# [20:08:09] System has 12 cores.
# [20:08:09] Will use maximum of 8 cores.
# [20:08:09] Annotating as >>> Bacteria <<<
# [20:08:09] Generating locus_tag from '/home/tiago/documentos/github/ARG-Sentinel/suberror/plasmids_annot/pSW732BN43.fasta' contents.
# [20:08:09] Setting --locustag CCDKKEHC from MD5 ccd44e1c4dfeedb64f1331d8535e7c73
# [20:08:09] Creating new output folder: /home/tiago/documentos/github/ARG-Sentinel/suberror/plasmids_annot/annot/pSW732BN43
# [20:08:09] Running: mkdir -p \/home\/tiago\/documentos\/github\/ARG\-Sentinel\/suberror\/plasmids_annot\/annot\/pSW732BN43
# [20:08:09] Using filename prefix: pSW732BN43.XXX
# [20:08:09] Setting HMMER_NCPU=1
# ...
